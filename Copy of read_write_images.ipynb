# %%
import numpy as np

# %%
from PIL import Image, ImageFont, ImageDraw

# %%
#from PIL.ImageChops import add, subtract, multiply, difference, screen

# %%
#import PIL.ImageStat as stat

# %%
from skimage.io import imread, imsave, imshow, show, imread_collection,imshow_collection

# %%
from skimage import color, viewer, exposure, img_as_float, data
#from skimage.transform import SimilarityTransform, warp, swirl
#from skimage.util import invert, random_noise, montage
import matplotlib.image as mpimg
import matplotlib.pylab as plt
#from scipy.ndimage import affine_transform, zoom
from scipy import misc
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Viewer requires Qt
#   """Entry point for launching an IPython kernel.

# %%
from google.colab import files
file1=files.upload()
# Out:
#      <input type="file" id="files-971daa0f-8b43-4c9a-8d3a-e361ca4f1ebf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-971daa0f-8b43-4c9a-8d3a-e361ca4f1ebf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving img1.jpg to img1.jpg

# %%
import cv2
im=cv2.imread('/content/img1.jpg')

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(im)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7FE40B7FA650>

# %%
cv2.imwrite('/content/img2.jpg', im)
# Out:
# True

# %%
im1=Image.open('/content/img1.jpg')

# %%
print(im1.width, im1.height, im1.mode, im1.format, type(im1))
# Out:
# 275 183 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
im1.show()

# %%
im1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x7FE409EAA690>

# %%
im1_gray=im1.convert('L')

# %%
im1_gray
# Out:
# <PIL.Image.Image image mode=L size=275x183 at 0x7FE409D74590>

# %%
im1_gray.save('/content/img2_gray.jpg')

# %%
im2=Image.open('/content/img2_gray.jpg')

# %%
im2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=275x183 at 0x7FE4099C13D0>

# %%
im3=mpimg.imread('/content/img1.jpg')

# %%
type(im3)
# Out:
# numpy.ndarray

# %%
im3.shape
# Out:
# (183, 275, 3)

# %%
im3.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(im3)

# %%
im4=im3

# %%
type(im4)
# Out:
# numpy.ndarray

# %%
plt.savefig('img3.jpg')

# %%
im5=mpimg.imread('/content/img3.jpg')
plt.imshow(im5)

# %%
im5
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
im3
# Out:
# array([[[ 65, 115, 204],
#         [ 65, 115, 204],
#         [ 65, 115, 204],
#         ...,
#         [ 89, 121,  56],
#         [ 89, 121,  56],
#         [ 89, 121,  56]],
#
#        [[ 65, 115, 204],
#         [ 65, 115, 204],
#         [ 66, 116, 205],
#         ...,
#         [ 92, 124,  59],
#         [ 92, 124,  59],
#         [ 92, 124,  59]],
#
#        [[ 66, 116, 205],
#         [ 66, 116, 205],
#         [ 66, 116, 205],
#         ...,
#         [ 94, 126,  61],
#         [ 94, 126,  61],
#         [ 94, 126,  61]],
#
#        ...,
#
#        [[ 99, 116,  38],
#         [101, 119,  45],
#         [ 97, 117,  46],
#         ...,
#         [ 96, 121,  56],
#         [ 75, 100,  35],
#         [ 56,  81,  16]],
#
#        [[ 94, 111,  40],
#         [103, 120,  50],
#         [101, 122,  55],
#         ...,
#         [ 94, 118,  56],
#         [ 71,  95,  33],
#         [ 51,  75,  13]],
#
#        [[ 89, 109,  40],
#         [102, 121,  55],
#         [103, 123,  60],
# ...

# %%
im6=imread('/content/img1.jpg')

# %%
imshow(im6)

# %%
im6.shape
# Out:
# (183, 275, 3)

# %%
import imageio

# %%
im7=imageio.imread('/content/img1.jpg')

# %%
plt.imshow(im7)
